# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge23amury/edd_1358_2021/blob/master/Tarea9_1358.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BoundedPriorityQueue:
	def __init__(self,niveles):
		if niveles < 1:
			return None
		self.__data = [[] for x in range(niveles)]
		self.__size = 0


	def is_empty(self):
		return len(self.__data) == 0


	def length(self):
		return len(self.__data)
  
  
	def enqueue(self,prioridad , elem):
		if (type(prioridad) is not int) or (prioridad > len(self.__data)-1) or (prioridad < 0) :
			print("'Fuera de rango establecido'")
		else:
			self.__data[prioridad].append(elem)
			self.__size += 1


	def dequeue(self):
		for i in self.__data:
			if len(i) > 0:
				self.__size -= 1
				return i.pop(0)
    
    
	def to_string(self):
		cont = 0
		for i in self.__data:
			for j in i:
				if cont == 0:
					print(f"|{j}| <maxima prioridad>")
				elif cont == self.__size-1:
					print(f"|{j}| <minima prioridad>")
				else:
					print(f'|{j}|')
				cont += 1

# %%
titanic = BoundedPriorityQueue(6)
titanic.enqueue(4,'Maestre')
titanic.enqueue(2,'Niños')
titanic.enqueue(4,'Mecánico')
titanic.enqueue(3,'Mujeres')
titanic.enqueue(2,'3ra edad')
titanic.enqueue(1,'Niñas')
titanic.enqueue(3,'Hombres')
titanic.enqueue(4,'Vigia')
titanic.enqueue(5,'Capitán')
titanic.enqueue(4,'Timonel')

# esta fuera del rango que ya establecimos
titanic.enqueue(6,'Polison') 

titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
titanic.dequeue()
titanic.to_string()
# Out:
# 'Fuera de rango establecido'
# |Niñas| <maxima prioridad>
# |Niños|
# |3ra edad|
# |Mujeres|
# |Hombres|
# |Maestre|
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Niños| <maxima prioridad>
# |3ra edad|
# |Mujeres|
# |Hombres|
# |Maestre|
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |3ra edad| <maxima prioridad>
# |Mujeres|
# |Hombres|
# |Maestre|
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Mujeres| <maxima prioridad>
# |Hombres|
# |Maestre|
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Hombres| <maxima prioridad>
# |Maestre|
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Maestre| <maxima prioridad>
# |Mecánico|
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Mecánico| <maxima prioridad>
# |Vigia|
# |Timonel|
# |Capitán| <minima prioridad>
# |Vigia| <maxima prioridad>
# |Timonel|
# |Capitán| <minima prioridad>
# |Timonel| <maxima prioridad>
# ...
